# %% [markdown]
# # Linear Regression
# Assumptions :
#     1. Data is normally distributed
#     2. Error should be normally distributed
#     3.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
df = pd.read_csv("automobileEDA.xls")

# %%
from sklearn.linear_model import LinearRegression

# %%
ln = LinearRegression()

# %%
x = df[['highway-mpg']]
y = df[['price']]

# %%
x.head()
# Out:
#    highway-mpg
# 0           27
# 1           27
# 2           26
# 3           30
# 4           22

# %%
y.head()
# Out:
#      price
# 0  13495.0
# 1  16500.0
# 2  16500.0
# 3  13950.0
# 4  17450.0

# %% [markdown]
# here we are trying to find relation between highway-mpg and price.
# as highway-mpg increase price descreases
# Fit method is internally doing ordinary least square function which is minimizing distance between data points (yi)and line(yˆ)
#
# we are taking squaring distances : because
# - maximize error
# - getting positive result
# - data points can be above or below line

# %%
ln.fit(x,y) # linear regression model # here model is ready
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
#get intercept

# %%
ln.intercept_
# Out:
# array([38423.30585816])

# %%
ln.coef_
# Out:
# array([[-821.73337832]])

# %% [markdown]
# # B0 + Bx = 38423 - (821)(20)

# %%
yhat = ln.predict(x)

# %%
yhat
# Out:
# array([[16236.50464347],
#        [16236.50464347],
#        [17058.23802179],
#        [13771.3045085 ],
#        [20345.17153508],
#        [17879.97140011],
#        [17879.97140011],
#        [17879.97140011],
#        [21988.63829172],
#        [14593.03788682],
#        [14593.03788682],
#        [15414.77126514],
#        [15414.77126514],
#        [17879.97140011],
#        [20345.17153508],
#        [20345.17153508],
#        [21988.63829172],
#        [-5128.5631929 ],
#        [ 3088.77059031],
#        [ 3088.77059031],
#        [ 4732.23734696],
#        [ 7197.43748192],
#        [13771.3045085 ],
#        [ 7197.43748192],
#        [ 7197.43748192],
#        [ 7197.43748192],
#        [13771.3045085 ],
#        [13771.3045085 ],
#        [18701.70477843],
#        [-5950.29657123],
#        [ 7197.43748192],
#        [ 3910.50396864],
#        [10484.37099521],
#        [10484.37099521],
#        [10484.37099521],
#        [10484.37099521],
#        [11306.10437353],
# ...

# %%
price = 38423 - (821.73)*(20)

# %%
price
# Out:
# 21988.4

# %%
price = 38423 - (821.73)*(x)
price
# Out:
#      highway-mpg
# 0       16236.29
# 1       16236.29
# 2       17058.02
# 3       13771.10
# 4       20344.94
# 5       17879.75
# 6       17879.75
# 7       17879.75
# 8       21988.40
# 9       14592.83
# 10      14592.83
# 11      15414.56
# 12      15414.56
# 13      17879.75
# 14      20344.94
# 15      20344.94
# 16      21988.40
# 17      -5128.69
# 18       3088.61
# 19       3088.61
# 20       4732.07
# 21       7197.26
# 22      13771.10
# 23       7197.26
# 24       7197.26
# 25       7197.26
# 26      13771.10
# 27      13771.10
# 28      18701.48
# 29      -5950.42
# ..           ...
# 171     12127.64
# 172     12127.64
# 173     12127.64
# 174     18701.48
# 175     18701.48
# 176     18701.48
# 177     18701.48
# 178       623.42
# 179     10484.18
# 180       623.42
# 181     10484.18
# 182     10484.18
# 183      3910.34
# 184     12127.64
# 185     14592.83
# 186     14592.83
# 187     18701.48
# 188      7197.26
# 189     12949.37
# 190     15414.56
# ...

# %%
# price is negative somewhere, which is not possible 
#so, center and scale data.and then 
if predict values are negative then how to deal with this???? Exercise

# %% [markdown]
# # Multiple linear regression

# %%
z = df [['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]

# %%
ln.fit(z, df[['price']])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
yhat = ln.predict(z)
yhat
# Out:
# array([[13699.11161184],
#        [13699.11161184],
#        [19051.65470233],
#        [10620.36193015],
#        [15521.31420211],
#        [13869.66673213],
#        [15456.16196732],
#        [15974.00907672],
#        [17612.35917161],
#        [10722.32509097],
#        [10722.32509097],
#        [17804.80307397],
#        [18063.72662867],
#        [19320.78745066],
#        [26968.56492801],
#        [27674.72007721],
#        [28191.0677239 ],
#        [  650.62317688],
#        [ 5648.50489642],
#        [ 5813.27443123],
#        [ 5478.81383232],
#        [ 5370.64136587],
#        [ 8739.61952024],
#        [ 5799.04215638],
#        [ 5902.61157827],
#        [ 5902.61157827],
#        [ 9036.2046829 ],
#        [11863.43973759],
#        [18767.70667001],
#        [ 4808.3090102 ],
#        [ 5693.32889063],
#        [ 4006.47212651],
#        [ 6118.73075572],
#        [ 6194.05397163],
#        [ 6448.26982534],
#        [ 6514.17763926],
#        [ 9478.65495235],
# ...

# %%
# y = B0 +  B1x1 + B2x2 + B3x3 + B4x4

# %%
ln.intercept_
# Out:
# array([-15806.62462633])

# %%
ln.coef_
# Out:
# array([[53.49574423,  4.70770099, 81.53026382, 36.05748882]])

# %%
sns.regplot(x= 'highway-mpg', y= 'price', data= df)

# %% [markdown]
# # MODEL EVALUATION:
# Residuals plot:  used  to evaluate model
#     (yi-yhat) :
#     Residuals are to find observable pattern.
#     - to predict accuracy of model
#     - used for single variable (Find reason???????)-
#
#     - If observable pattern

# %%
width = 12
height = 10
plt.figure(figsize = (width, height))
sns.residplot(df['highway-mpg'], df['price'])
plt.show()

# %% [markdown]
# # Distribution Plot -used  to evaluate model

# %%
y_hat = ln.predict(z)

# %%
plt.figure(figsize = (width, height))

ax1 = sns.distplot(df['price'], hist = False, color='r',label = 'actual value')
sns.distplot (y_hat ,hist= False, label= "Fitted values", ax= ax1)
plt.title("Actual vs Predicted values for Price")
plt.xlabel("Price in dollar")
plt.ylabel("Proportion of cars")
plt.show()
plt.close()
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize = (width, height))

ax1 = sns.distplot(df['price'], hist = True, color='r',label = 'actual value')
sns.distplot (y_hat ,hist= True, label= "Fitted values", ax= ax1)
plt.title("Actual vs Predicted values for Price")
plt.xlabel("Price in dollar")
plt.ylabel("Proportion of cars")
plt.show()
plt.close()

# %%
ln = LinearRegression()
x = df[['highway-mpg']]
y = df[['price']]
ln.fit(x,y)
y_hat = ln.predict(x)

plt.figure(figsize = (width, height))

ax1 = sns.distplot(df['price'], hist = False, color='r',label = 'actual value')
sns.distplot (y_hat ,hist= False, label= "Fitted values", ax= ax1)
plt.title("Actual vs Predicted values for Price")
plt.xlabel("Price in dollar")
plt.ylabel("Proportion of cars")
plt.show()
plt.close()
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
ln = LinearRegression()
x = df[['highway-mpg']]
y = df[['price']]
ln.fit(x,y)
y_hat = ln.predict(x)

plt.figure(figsize = (width, height))

ax1 = sns.distplot(df['price'], hist = True, color='r',label = 'actual value')
sns.distplot (y_hat ,hist= True, label= "Fitted values", ax= ax1)
plt.title("Actual vs Predicted values for Price")
plt.xlabel("Price in dollar")
plt.ylabel("Proportion of cars")
plt.show()
plt.close()
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# # Polynomial Regression
#  - Special case of linear regression model useful for curvilinear relationships
#  curvilinear relationships
#  - By squaring or setting higher order forms for pedictor variables
#  Before polynomial regression we have to preprocess data .
# We have to change degree of data and then build the model.
#
# - if we changed degree more, it will overfit

# %%
x = df['highway-mpg']
y = df['price']

# %%
import numpy as np
f = np.polyfit(x, y, 3)
p = np.poly1d(f)
print(p)
PlotPolly(p,x,y,'highway-mpg')
# Out:
#         3         2
# -1.557 x + 204.8 x - 8965 x + 1.379e+05

# %%
def PlotPolly(model, independent_variable, dependent_variable, Name):
    x_new = np.linspace(15,55,100)
    y_new = model(x_new)
    
    plt.plot(independent_variable, dependent_variable, '.', x_new, y_new, '-')
    plt.title("Poliynomial Fit")
    ax = plt.gca()
    fig = plt.gcf()
    plt.xlabel(Name)
    plt.show()
    plt.close()

# %%
def PlotPolly1(model, Name):
    x_new = np.linspace(15,55,100)
    y_new = model(x_new)
    
    plt.plot(x, y, '.')
    plt.title("Polynomial Fit")
    ax = plt.gca()
    fig = plt.gcf()
    plt.xlabel(Name)
    plt.show()
    plt.close()

# %%
import numpy as np
f = np.polyfit(x, y, 3)
p = np.poly1d(f)
print(p)
PlotPolly1(p,'highway-mpg')
# Out:
#         3         2
# -1.557 x + 204.8 x - 8965 x + 1.379e+05

# %%
import numpy as np
f = np.polyfit(x, y, 6)
p = np.poly1d(f)
print(p)
PlotPolly(p,x,y,'highway-mpg')
# Out:
#            6          5         4         3             2
# 0.0007207 x - 0.1559 x + 13.69 x - 625.9 x + 1.575e+04 x - 2.088e+05 x + 1.171e+06

# %%
from sklearn.preprocessing import PolynomialFeatures
pr = PolynomialFeatures(degree= 4)
pr
# Out:
# PolynomialFeatures(degree=4, include_bias=True, interaction_only=False)

# %%
z_pr = pr.fit_transform(z)

# %%
z_pr
print(z.shape)
print(z_pr.shape)
# Out:
# (201, 4)
# (201, 70)

# %%
type(z_pr)
# Out:
# numpy.ndarray

# %%
z_pr = pd.DataFrame(z_pr)

# %%
ln.fit(z_pr, df[['price']])
yhat = ln.predict(z_pr)
plt.figure(figsize = (width, height))

ax1 = sns.distplot(df['price'], hist = False, color='r',label = 'actual value')
sns.distplot (yhat ,hist= False, label= "Fitted values", ax= ax1)
plt.title("Actual vs Predicted values for Price")
plt.xlabel("Price in dollar")
plt.ylabel("Proportion of cars")
plt.show()
plt.close()
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
